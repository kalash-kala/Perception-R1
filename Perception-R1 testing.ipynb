# %%
import pandas as pd

# %%
df_stratified = pd.read_parquet("/home/kalashkala/Datasets/VQAv2/vqa_stratified_100.parquet")
df_stratified
# Out:
#           question_type multiple_choice_answer  \
# 0    what color are the                  green
# 1         what sport is                 soccer
# 2               is this                     no
# 3     what color is the                 silver
# 4              are they                    yes
# ..                  ...                    ...
# 695         what is the   shadow from its head
# 696   what color is the                  brown
# 697            how many                      9
# 698      what is on the                   food
# 699   what color is the                  brown
#
#                                                answers  image_id answer_type  \
# 0    [{'answer': 'green', 'answer_confidence': 'may...    368602       other
# 1    [{'answer': 'soccer', 'answer_confidence': 'ye...    447917       other
# 2    [{'answer': 'no', 'answer_confidence': 'yes', ...    436605      yes/no
# 3    [{'answer': 'blue', 'answer_confidence': 'yes'...    118778       other
# ...
